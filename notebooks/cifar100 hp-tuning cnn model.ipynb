# %%
"""cifar100 hp-tuning cnn model: interactive notebook experiment.

Legacy Hyperas experiment template. create_data supplies image or stored-feature arrays,
and create_model contains double-brace search expressions that Hyperas expands before
execution. These templates retain the historical helper signatures and optimizer options
written in their cells.

The search choices, best-score globals, trial counter, dataset/model paths, and fit
arguments below are its inputs. Local function docstrings explain each objective and
preprocessing branch. Outputs include trial losses, logs, and saved best models where
the objective explicitly writes them. Running cells may initialize GPU resources,
load/download data, train models, and overwrite configured artifact paths.
"""

from __future__ import print_function

import os


os.chdir("../")

# %%
from hyperopt import STATUS_OK, Trials, tpe
from hyperas.distributions import choice, uniform, loguniform
from hyperas import optim

import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, metrics
from tensorflow.keras.datasets import cifar10

from sklearn.model_selection import train_test_split

import numpy as np

from utils import (get_compile_args, get_callbacks, 
                hyperas_path, i, best_acc, save_logs, 
                init, load_samples, load_cifar100)

# %%
def create_data():
    """Load the CIFAR100 image splits used by the Hyperas CNN search.

    Calls the notebook init helper before the dataset loader. Data loading may
    download/cache images and initialize TensorFlow resources. The function has no
    selectable preprocessing mode; this trial family fixes preprocess="min-max" and
    verbose=0.

    Args:
        None.

    Returns:
        tuple[np.ndarray, ...]: (x_train, y_train, x_val, y_val, x_test, y_test), with
        min-max image inputs and sparse class IDs.
    """

    init()

    x_train, y_train, x_val, y_val, x_test, y_test = load_cifar100(preprocess="min-max", verbose=0)

    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def create_model(x_train, y_train, x_val, y_val, x_test, y_test):
    """Run one legacy Hyperas CNN trial for 100-class CIFAR classification.

    Hyperas replaces the double-brace choice expressions before calling this template.
    Choices control convolution groups, normalization, pooling, dropout, and optimizer.
    The first two convolution groups are unconditional; the three/four/five mode appends
    the groups written in its branch, so the name is not the total group count. Training
    uses batch size 128 and at most 100 epochs with validation callbacks. The objective
    updates notebook globals best_acc and i, appends trial logs, and may overwrite the
    best HDF5 model. Test arrays are unused.

    Args:
        x_train (np.ndarray): Training images with shape (N, 32, 32, 3), min-max
            preprocessed by create_data.
        y_train (np.ndarray): Training class IDs aligned with the first axis of the
            training inputs.
        x_val (np.ndarray): Validation images used by fit callbacks and final trial
            accuracy.
        y_val (np.ndarray): Validation class IDs used for the optimization score.
        x_test (np.ndarray): Held-out images accepted for the Hyperas data contract;
            unused in this objective.
        y_test (np.ndarray): Held-out class IDs accepted for the data contract; unused
            in this objective.

    Returns:
        dict[str, object]: loss is negative validation accuracy, status is STATUS_OK,
        and model is None; the trained model is saved separately only when it improves
        best_acc.
    """

    def conv_layer(kernels, filter_size, batch_norm, num=1):
        """Build a repeated convolution stage followed by spatial max pooling.

        Layer weights are created according to Keras build timing. The helper constructs a
        separate stage on each call; it does not share weights or compile the result.

        Args:
            kernels (int): Output filters in every convolution in this stage.
            filter_size (int | tuple[int, int]): Spatial kernel size for same-padded
                convolutions.
            batch_norm (str): The literal "yes" inserts BatchNormalization and disables
                convolution biases; other values keep biases and omit normalization.
            num (int): Number of Conv2D/ReLU repetitions before one same-padded 2x2 max
                pool. Defaults to ``1``.

        Returns:
            tf.keras.Sequential: New stage that preserves spatial dimensions within each
            convolution and reduces them to ceil(H/2), ceil(W/2) with same-padded stride-two
            max pooling.
        """

        model = models.Sequential()

        for _ in range(num):
            # Batch normalization disables convolution bias and adds normalization; other
            # choices retain bias.
            model.add(layers.Conv2D(kernels, filter_size, padding="same", use_bias=False if batch_norm=="yes" else True))
            # Batch normalization disables convolution bias and adds normalization; other
            # choices retain bias.
            model.add(layers.BatchNormalization()) if batch_norm=="yes" else None
            model.add(layers.Activation("relu"))

        model.add(layers.MaxPooling2D(2, padding="same"))

        return model


    global best_acc, i


    conv_num = {{choice(["three", "four", "five"])}}
    first_conv_filter_size = {{choice([3, 5, 7, 9])}}
    batch_norm = {{choice(["yes", "no"])}}
    global_pooling_type = {{choice(["max", "avg"])}}

    convgp1_kernels = {{choice([4, 8, 16, 32, 64])}}
    convgp2_kernels = convgp1_kernels * {{choice([1, 2])}}
    convgp3_kernels = convgp2_kernels * {{choice([1, 2])}}
    convgp4_kernels = convgp3_kernels * {{choice([1, 2])}}
    convgp5_kernels = convgp4_kernels * {{choice([1, 2])}}
    
    convgp2_num = {{choice([1, 2, 3])}}
    convgp3_num = {{choice([1, 2, 3])}}
    convgp4_num = {{choice([1, 2, 3])}}
    convgp5_num = {{choice([1, 2, 3])}}

    dense_dropout = {{choice([0.0, 0.1, 0.20, 0.25, 0.4, 0.5])}}

    lr = {{choice([0.0001, 0.0003, 0.001, 0.003, 0.01, 0.03, 0.1])}}
    momentum = {{choice([0.0, 0.01, 0.03, 0.1, 0.3, 0.5, 0.8, 0.9, 0.99])}}
    weight_decay = {{choice([0.0, 0.0001, 0.0003, 0.001, 0.003, 0.01, 0.03, 0.1])}}
    opt_choice = {{choice(["sgd", "rmsprop", "adam", "nadam", "adamax", "adamw"])}}


    model = models.Sequential(name="cifar100_cnn_model_00")

    model.add(layers.Input(shape=(32, 32, 3)))
    model.add(conv_layer(convgp1_kernels, first_conv_filter_size, batch_norm))
    model.add(conv_layer(convgp2_kernels, 3, batch_norm, convgp2_num))

    # Append the three-mode convolution groups after the two unconditional stages.
    if conv_num == "three":
        model.add(conv_layer(convgp2_kernels, 3, batch_norm, convgp2_num))
        model.add(conv_layer(convgp3_kernels, 3, batch_norm, convgp3_num))
        
    # Append the four-mode convolution groups after the two unconditional stages.
    elif conv_num == "four":
       model.add(conv_layer(convgp2_kernels, 3, batch_norm, convgp2_num))
       model.add(conv_layer(convgp3_kernels, 3, batch_norm, convgp3_num))
       model.add(conv_layer(convgp4_kernels, 3, batch_norm, convgp4_num))
            
    # Append the five-mode convolution groups after the two unconditional stages.
    elif conv_num == "five":
        model.add(conv_layer(convgp2_kernels, 3, batch_norm, convgp2_num))
        model.add(conv_layer(convgp3_kernels, 3, batch_norm, convgp3_num))
        model.add(conv_layer(convgp4_kernels, 3, batch_norm, convgp4_num))
        model.add(conv_layer(convgp5_kernels, 3, batch_norm, convgp5_num))

    # Reduce each channel by its spatial maximum for the max-pooling treatment.
    if global_pooling_type == "max":
        model.add(layers.GlobalMaxPooling2D())

    # Reduce each channel by spatial average for the average-pooling treatment.
    elif global_pooling_type == "avg":
        model.add(layers.GlobalAveragePooling2D())

    model.add(layers.Dropout(dense_dropout))
    model.add(layers.Dense(100, activation="softmax"))

    sgd = optimizers.SGD(learning_rate=lr, momentum=momentum, decay=weight_decay, nesterov=True)
    rmsprop = optimizers.RMSprop(learning_rate=lr, momentum=momentum, decay=weight_decay)
    adam = optimizers.Adam(learning_rate=lr, decay=weight_decay)
    nadam = optimizers.Nadam(learning_rate=lr, decay=weight_decay)
    adamax = optimizers.Adamax(learning_rate=lr, decay=weight_decay)
    adamw = optimizers.experimental.AdamW(learning_rate=lr, weight_decay=weight_decay)

    # Use the sgd optimizer for this sampled optimizer choice.
    if opt_choice == "sgd":
        optimizer = sgd
    # Use the rmsprop optimizer for this sampled optimizer choice.
    elif opt_choice == "rmsprop":
        optimizer = rmsprop
    # Use the adam optimizer for this sampled optimizer choice.
    elif opt_choice == "adam":
        optimizer = adam
    # Use the nadam optimizer for this sampled optimizer choice.
    elif opt_choice == "nadam":
        optimizer = nadam
    # Use the adamax optimizer for this sampled optimizer choice.
    elif opt_choice == "adamax":
        optimizer = adamax
    # Use the adamw optimizer for this sampled optimizer choice.
    elif opt_choice == "adamw":
        optimizer = adamw

    model.compile(**get_compile_args(optimizer=optimizer))


    history = model.fit(
        x_train, y_train,
        batch_size=128,
        epochs=100,
        validation_data=(x_val, y_val),
        callbacks=get_callbacks(min_delta=1e-2, verbose=0),
        verbose=0,
    ).history

    val_acc = metrics.SparseCategoricalAccuracy()(y_val, model.predict(x_val, verbose=0))

    # Save this classifier only when validation accuracy improves the previous best.
    if val_acc > best_acc:
        best_acc = val_acc
        model.save(os.path.join(hyperas_path, f"{model.name}.h5"))

    save_logs(model.name, i, val_acc, best_acc, 
            search_space=[conv_num, first_conv_filter_size, batch_norm, global_pooling_type, 
                        convgp1_kernels, convgp2_kernels, convgp3_kernels, convgp4_kernels, convgp5_kernels, 
                        convgp2_num, convgp3_num, convgp4_num, convgp5_num, dense_dropout, lr, momentum, 
                        weight_decay, opt_choice], 
            names=["conv_num", "first_conv_filter_size", "batch_norm", "global_pooling_type", 
                "convgp1_kernels", "convgp2_kernels", "convgp3_kernels", "convgp4_kernels", "convgp5_kernels", 
                "convgp2_num", "convgp3_num", "convgp4_num", "convgp5_num", "dense_dropout", "lr", "momentum", 
                "weight_decay", "opt_choice"], 
            where_to="file")

    i += 1


    return {"loss": -val_acc, "status": STATUS_OK, "model": None}

# %%
best_run, best_model = optim.minimize(
    model=create_model,
    data=create_data,
    algo=tpe.suggest,
    max_evals=200,
    trials=Trials(),
    notebook_name="notebooks/cifar100 hp-tuning cnn model"
)
# Out:
# >>> Imports:
# #coding=utf-8
#
# from __future__ import print_function
#
# try:
#     import os
# except:
#     pass
#
# try:
#     from hyperopt import STATUS_OK, Trials, tpe
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform, loguniform
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow.keras import layers, models, optimizers, metrics
# except:
#     pass
#
# try:
#     from tensorflow.keras.datasets import cifar10
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from utils import create_compile_args, create_callbacks_list, load_cifar100, init, hyperas_path, i, best_acc, save_logs
# except:
#     pass
#
# try:
#     from sklearn.metrics import classification_report
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'conv_num': hp.choice('conv_num', ["three", "four", "five"]),
#         'first_conv_filter_size': hp.choice('first_conv_filter_size', [3, 5, 7, 9]),
#         'batch_norm': hp.choice('batch_norm', ["yes", "no"]),
#         'global_pooling_type': hp.choice('global_pooling_type', ["max", "avg"]),
#         'convgp1_kernels': hp.choice('convgp1_kernels', [4, 8, 16, 32, 64]),
#         'convgp1_kernels_1': hp.choice('convgp1_kernels_1', [1, 2]),
#         'convgp1_kernels_2': hp.choice('convgp1_kernels_2', [1, 2]),
#         'convgp1_kernels_3': hp.choice('convgp1_kernels_3', [1, 2]),
#         'convgp1_kernels_4': hp.choice('convgp1_kernels_4', [1, 2]),
#         'convgp2_num': hp.choice('convgp2_num', [1, 2, 3]),
#         'convgp2_num_1': hp.choice('convgp2_num_1', [1, 2, 3]),
#         'convgp2_num_2': hp.choice('convgp2_num_2', [1, 2, 3]),
#         'convgp2_num_3': hp.choice('convgp2_num_3', [1, 2, 3]),
#         'dense_dropout': hp.choice('dense_dropout', [0.0, 0.1, 0.20, 0.25, 0.4, 0.5]),
#         'lr': hp.choice('lr', [0.0001, 0.0003, 0.001, 0.003, 0.01, 0.03, 0.1]),
#         'momentum': hp.choice('momentum', [0.0, 0.01, 0.03, 0.1, 0.3, 0.5, 0.8, 0.9, 0.99]),
#         'weight_decay': hp.choice('weight_decay', [0.0, 0.0001, 0.0003, 0.001, 0.003, 0.01, 0.03, 0.1]),
#         'opt_choice': hp.choice('opt_choice', ["sgd", "rmsprop", "adam", "nadam", "adamax", "adamw"]),
#     }
#
# >>> Data
#  1:
#  2: init()
#  3:
#  4: x_train, y_train, x_val, y_val, x_test, y_test = load_cifar100(verbose=0)
#  5:
#  6:
#  7:
#  8:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:     def conv_layer(kernels, filter_size, batch_norm, num=1):
#    4:         model = models.Sequential()
#    5:
#    6:         for _ in range(num):
#    7:             model.add(layers.Conv2D(kernels, filter_size, padding="same", use_bias=False if batch_norm=="yes" else True))
#    8:             model.add(layers.BatchNormalization()) if batch_norm=="yes" else None
#    9:             model.add(layers.Activation("relu"))
#   10:
#   11:         model.add(layers.MaxPooling2D(2, padding="same"))
#   12:
#   13:         return model
#   14:
#   15:
#   16:     global best_acc, i
#   17:
#   18:
#   19:     conv_num = space['conv_num']
#   20:     first_conv_filter_size = space['first_conv_filter_size']
#   21:     batch_norm = space['batch_norm']
#   22:     global_pooling_type = space['global_pooling_type']
#   23:
#   24:     convgp1_kernels = space['convgp1_kernels']
#   25:     convgp2_kernels = convgp1_kernels * space['convgp1_kernels_1']
#   26:     convgp3_kernels = convgp2_kernels * space['convgp1_kernels_2']
#   27:     convgp4_kernels = convgp3_kernels * space['convgp1_kernels_3']
#   28:     convgp5_kernels = convgp4_kernels * space['convgp1_kernels_4']
#   29:
#   30:     convgp2_num = space['convgp2_num']
#   31:     convgp3_num = space['convgp2_num_1']
#   32:     convgp4_num = space['convgp2_num_2']
#   33:     convgp5_num = space['convgp2_num_3']
#   34:
#   35:     dense_dropout = space['dense_dropout']
#   36:
#   37:     lr = space['lr']
#   38:     momentum = space['momentum']
#   39:     weight_decay = space['weight_decay']
#   40:     opt_choice = space['opt_choice']
#   41:
#   42:
#   43:     model = models.Sequential(name="cifar100_cnn_model_00")
#   44:
#   45:     model.add(layers.Input(shape=(32, 32, 3)))
#   46:     model.add(conv_layer(convgp1_kernels, first_conv_filter_size, batch_norm))
#   47:     model.add(conv_layer(convgp2_kernels, 3, batch_norm, convgp2_num))
#   48:
#   49:     if conv_num == "three":
#   50:         model.add(conv_layer(convgp2_kernels, 3, batch_norm, convgp2_num))
#   51:         model.add(conv_layer(convgp3_kernels, 3, batch_norm, convgp3_num))
#   52:
#   53:     elif conv_num == "four":
#   54:        model.add(conv_layer(convgp2_kernels, 3, batch_norm, convgp2_num))
#   55:        model.add(conv_layer(convgp3_kernels, 3, batch_norm, convgp3_num))
#   56:        model.add(conv_layer(convgp4_kernels, 3, batch_norm, convgp4_num))
#   57:
#   58:     elif conv_num == "five":
#   59:         model.add(conv_layer(convgp2_kernels, 3, batch_norm, convgp2_num))
#   60:         model.add(conv_layer(convgp3_kernels, 3, batch_norm, convgp3_num))
#   61:         model.add(conv_layer(convgp4_kernels, 3, batch_norm, convgp4_num))
#   62:         model.add(conv_layer(convgp5_kernels, 3, batch_norm, convgp5_num))
#   63:
#   64:     if global_pooling_type == "max":
#   65:         model.add(layers.GlobalMaxPooling2D())
#   66:
#   67:     elif global_pooling_type == "avg":
#   68:         model.add(layers.GlobalAveragePooling2D())
#   69:
#   70:     model.add(layers.Dropout(dense_dropout))
#   71:     model.add(layers.Dense(100, activation="softmax"))
#   72:
#   73:     sgd = optimizers.SGD(learning_rate=lr, momentum=momentum, decay=weight_decay, nesterov=True)
#   74:     rmsprop = optimizers.RMSprop(learning_rate=lr, momentum=momentum, decay=weight_decay)
#   75:     adam = optimizers.Adam(learning_rate=lr, decay=weight_decay)
#   76:     nadam = optimizers.Nadam(learning_rate=lr, decay=weight_decay)
#   77:     adamax = optimizers.Adamax(learning_rate=lr, decay=weight_decay)
#   78:     adamw = optimizers.experimental.AdamW(learning_rate=lr, weight_decay=weight_decay)
#   79:
#   80:     if opt_choice == "sgd":
#   81:         optimizer = sgd
#   82:     elif opt_choice == "rmsprop":
#   83:         optimizer = rmsprop
#   84:     elif opt_choice == "adam":
#   85:         optimizer = adam
#   86:     elif opt_choice == "nadam":
#   87:         optimizer = nadam
#   88:     elif opt_choice == "adamax":
#   89:         optimizer = adamax
#   90:     elif opt_choice == "adamw":
#   91:         optimizer = adamw
#   92:
#   93:     model.compile(**create_compile_args(optimizer=optimizer))
#   94:
#   95:
#   96:     history = model.fit(
#   97:         x_train, y_train,
#   98:         batch_size=128,
#   99:         epochs=100,
#  100:         validation_data=(x_val, y_val),
#  101:         callbacks=create_callbacks_list(min_delta=1e-2, verbose=0),
#  102:         verbose=0,
#  103:     ).history
#  104:
#  105:     val_acc = metrics.SparseCategoricalAccuracy()(y_val, model.predict(x_val, verbose=0))
#  106:
#  107:     if val_acc > best_acc:
#  108:         best_acc = val_acc
#  109:         model.save(os.path.join(hyperas_path, f"{model.name}.h5"))
#  110:
#  111:     save_logs(model.name, i, val_acc, best_acc,
#  112:             search_space=[conv_num, first_conv_filter_size, batch_norm, global_pooling_type,
#  113:                         convgp1_kernels, convgp2_kernels, convgp3_kernels, convgp4_kernels, convgp5_kernels,
#  114:                         convgp2_num, convgp3_num, convgp4_num, convgp5_num, dense_dropout, lr, momentum,
#  115:                         weight_decay, opt_choice],
#  116:             names=["conv_num", "first_conv_filter_size", "batch_norm", "global_pooling_type",
#  117:                 "convgp1_kernels", "convgp2_kernels", "convgp3_kernels", "convgp4_kernels", "convgp5_kernels",
#  118:                 "convgp2_num", "convgp3_num", "convgp4_num", "convgp5_num", "dense_dropout", "lr", "momentum",
#  119:                 "weight_decay", "opt_choice"],
#  120:             where_to="file")
#  121:
#  122:     i += 1
#  123:
#  124:
#  125:     return {"loss": -val_acc, "status": STATUS_OK, "model": None}
#  126:
#  95%|█████████▌| 190/200 [7:24:40<12:25, 74.51s/trial, best loss: -0.4830999970436096]     WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# 100%|██████████| 200/200 [7:36:57<00:00, 137.09s/trial, best loss: -0.4846000075340271]

# %%
best_run
# Out:
# {'batch_norm': 0,
#  'conv_num': 0,
#  'convgp1_kernels': 4,
#  'convgp1_kernels_1': 1,
#  'convgp1_kernels_2': 1,
#  'convgp1_kernels_3': 1,
#  'convgp1_kernels_4': 0,
#  'convgp2_num': 1,
#  'convgp2_num_1': 0,
#  'convgp2_num_2': 2,
#  'convgp2_num_3': 1,
#  'dense_dropout': 2,
#  'first_conv_filter_size': 0,
#  'global_pooling_type': 1,
#  'lr': 3,
#  'momentum': 1,
#  'opt_choice': 5,
#  'weight_decay': 1}

# %%
from sklearn.metrics import classification_report


*_, x_test, y_test = create_data()
model = models.load_model(os.path.join(hyperas_path, "cifar100_cnn_model_00.h5"))
model.summary()

preds = model.predict(x_test)
print(classification_report(y_test, np.argmax(preds, axis=-1), digits=4))
# Out:
# WARNING:tensorflow:Loading model from HDF5 will not restore the optimizer's weights, since the optimizer is an instance of `optimizer_experimental.Optimizer`
# Model: "cifar100_cnn_model_00"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_852 (Sequential)  (None, 16, 16, 64)       1984
#
#  sequential_853 (Sequential)  (None, 8, 8, 128)        222208
#
#  sequential_854 (Sequential)  (None, 4, 4, 128)        295936
#
#  sequential_855 (Sequential)  (None, 2, 2, 256)        295936
#
#  global_average_pooling2d_15  (None, 256)              0
#  3 (GlobalAveragePooling2D)
#
#  dropout_190 (Dropout)       (None, 256)               0
#
#  dense_190 (Dense)           (None, 100)               25700
#
# =================================================================
# Total params: 841,764
# Trainable params: 840,100
# Non-trainable params: 1,664
# _________________________________________________________________
# 313/313 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0     0.8391    0.7300    0.7807       100
#            1     0.6818    0.4500    0.5422       100
#            2     0.3506    0.2700    0.3051       100
#            3     0.2000    0.5300    0.2904       100
#            4     0.7778    0.0700    0.1284       100
#            5     0.5349    0.2300    0.3217       100
#            6     0.6186    0.6000    0.6091       100
#            7     0.4331    0.5500    0.4846       100
#            8     0.7639    0.5500    0.6395       100
#            9     0.5103    0.7400    0.6041       100
#           10     0.3259    0.4400    0.3745       100
#           11     0.3359    0.4400    0.3810       100
#           12     0.5588    0.3800    0.4524       100
#           13     0.2719    0.5900    0.3722       100
#           14     0.4118    0.4900    0.4475       100
#           15     0.4430    0.3500    0.3911       100
#           16     0.5294    0.5400    0.5347       100
#           17     0.7282    0.7500    0.7389       100
#           18     0.6087    0.4200    0.4970       100
#           19     0.4118    0.4900    0.4475       100
#           20     0.4969    0.8100    0.6160       100
#           21     0.8060    0.5400    0.6467       100
#           22     0.5658    0.4300    0.4886       100
#           23     0.4302    0.7400    0.5441       100
#           24     0.4826    0.8300    0.6103       100
#           25     0.2848    0.4700    0.3547       100
#           26     0.6857    0.2400    0.3556       100
#           27     0.3571    0.2000    0.2564       100
#           28     0.6636    0.7100    0.6860       100
#           29     0.7083    0.3400    0.4595       100
#           30     0.5349    0.4600    0.4946       100
#           31     0.6522    0.3000    0.4110       100
#           32     0.3721    0.4800    0.4192       100
#           33     0.6571    0.4600    0.5412       100
#           34     0.3391    0.5900    0.4307       100
#           35     0.3254    0.4100    0.3628       100
#           36     0.5854    0.4800    0.5275       100
#           37     0.6667    0.2600    0.3741       100
#           38     0.4167    0.3500    0.3804       100
#           39     0.7857    0.5500    0.6471       100
#           40     0.5541    0.4100    0.4713       100
#           41     0.4368    0.8300    0.5724       100
#           42     0.8222    0.3700    0.5103       100
#           43     0.7222    0.5200    0.6047       100
#           44     0.2500    0.2400    0.2449       100
#           45     0.4107    0.2300    0.2949       100
#           46     0.2599    0.4600    0.3321       100
#           47     0.3854    0.7400    0.5068       100
#           48     0.5931    0.8600    0.7020       100
#           49     0.7500    0.4500    0.5625       100
#           50     0.4444    0.1600    0.2353       100
#           51     0.5867    0.4400    0.5029       100
#           52     0.6190    0.3900    0.4785       100
#           53     0.5027    0.9200    0.6502       100
#           54     0.6731    0.7000    0.6863       100
#           55     0.2647    0.0900    0.1343       100
#           56     0.7400    0.7400    0.7400       100
#           57     0.6154    0.4000    0.4848       100
#           58     0.6304    0.5800    0.6042       100
#           59     0.4595    0.5100    0.4834       100
#           60     0.6154    0.8800    0.7243       100
#           61     0.8750    0.3500    0.5000       100
#           62     0.3544    0.8400    0.4985       100
#           63     0.7250    0.2900    0.4143       100
#           64     0.5938    0.1900    0.2879       100
#           65     0.2647    0.2700    0.2673       100
#           66     0.4400    0.6600    0.5280       100
#           67     0.4681    0.4400    0.4536       100
#           68     0.8488    0.7300    0.7849       100
#           69     0.5141    0.7300    0.6033       100
#           70     0.5126    0.6100    0.5571       100
#           71     0.6496    0.7600    0.7005       100
#           72     0.2500    0.2500    0.2500       100
#           73     0.3315    0.5900    0.4245       100
#           74     0.4762    0.2000    0.2817       100
#           75     0.8625    0.6900    0.7667       100
#           76     0.6320    0.7900    0.7022       100
#           77     0.7188    0.2300    0.3485       100
#           78     0.5849    0.3100    0.4052       100
#           79     0.5579    0.5300    0.5436       100
#           80     0.4651    0.2000    0.2797       100
#           81     0.3649    0.5400    0.4355       100
#           82     0.5959    0.8700    0.7073       100
#           83     0.5068    0.3700    0.4277       100
#           84     0.4330    0.4200    0.4264       100
#           85     0.6867    0.5700    0.6230       100
#           86     0.6087    0.5600    0.5833       100
#           87     0.6000    0.5700    0.5846       100
#           88     0.7761    0.5200    0.6228       100
#           89     0.2964    0.7500    0.4249       100
#           90     0.2864    0.6300    0.3937       100
#           91     0.8036    0.4500    0.5769       100
#           92     0.7576    0.2500    0.3759       100
#           93     0.4194    0.1300    0.1985       100
#           94     0.5196    0.9300    0.6667       100
#           95     0.7458    0.4400    0.5535       100
#           96     0.6308    0.4100    0.4970       100
#           97     0.4950    0.5000    0.4975       100
#           98     0.3750    0.1200    0.1818       100
#           99     0.7925    0.4200    0.5490       100
#
#     accuracy                         0.4929     10000
#    macro avg     0.5431    0.4929    0.4840     10000
# weighted avg     0.5431    0.4929    0.4840     10000
